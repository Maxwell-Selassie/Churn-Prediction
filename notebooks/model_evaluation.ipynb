# %%
# import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import joblib
import os

# %%
# load the datasets
import pandas as pd
try:
    x_train = pd.read_parquet('data/x_train.parquet')
    x_test = pd.read_parquet('data/x_test.parquet')
    y_train = pd.read_parquet('data/y_train.parquet')['y_train']
    y_test = pd.read_parquet('data/y_test.parquet')['y_test']
    df = pd.read_csv('data/preprocessed_df.csv')
    print('Files successfully loaded!')
except FileNotFoundError:
    print('Files not found!')
# Out:
# Files successfully loaded!

# %%
# load the best model
if os.path.exists('models/XGBClassifier_best_model.pkl'):
    best_model = joblib.load('models/XGBClassifier_best_model.pkl')
    print('Best model successfully loaded!')
else:
    raise ValueError('Model not found!')
from sklearn.model_selection import StratifiedKFold
cv = StratifiedKFold(n_splits=10,shuffle=True,random_state=42)
# Out:
# Best model successfully loaded!

# %%
# prediction model
from sklearn.calibration import CalibratedClassifierCV
calibrated_model = CalibratedClassifierCV(best_model,method='sigmoid',cv=cv)
calibrated_model.fit(x_train,y_train)
# Out:
# CalibratedClassifierCV(cv=StratifiedKFold(n_splits=10, random_state=42, shuffle=True),
#                        estimator=Pipeline(steps=[('preprocessor',
#                                                   ColumnTransformer(transformers=[('num',
#                                                                                    Pipeline(steps=[('impute',
#                                                                                                     SimpleImputer()),
#                                                                                                    ('scaler',
#                                                                                                     RobustScaler()),
#                                                                                                    ('poly',
#                                                                                                     PolynomialFeatures(degree=1,
#                                                                                                                        include_bias=False))]),
#                                                                                    Index(['Tenure', 'CityTier', 'WarehouseToHome', 'HourSpendOn...
#                                                                 feature_weights=None,
#                                                                 gamma=None,
#                                                                 grow_policy=None,
#                                                                 importance_type=None,
#                                                                 interaction_constraints=None,
#                                                                 learning_rate=0.5,
#                                                                 max_bin=None,
#                                                                 max_cat_threshold=None,
#                                                                 max_cat_to_onehot=None,
#                                                                 max_delta_step=None,
#                                                                 max_depth=9,
#                                                                 max_leaves=None,
#                                                                 min_child_weight=None,
#                                                                 missing=nan,
#                                                                 monotone_constraints=None,
#                                                                 multi_strategy=None,
#                                                                 n_estimators=200,
#                                                                 n_jobs=None,
#                                                                 num_parallel_tree=None, ...))]))

# %%
import joblib
joblib.dump(calibrated_model,'models/calibrated_model.pkl')
print('Calibrated model saved!')
# Out:
# Calibrated model saved!

# %%
y_probs = calibrated_model.predict_proba(x_test)[:,1]
threshold = 0.2
y_pred = (y_probs >= threshold).astype(int)

# %%
from sklearn.metrics import precision_recall_curve
precisions, recalls, thresholds = precision_recall_curve(y_test, y_probs)

import matplotlib.pyplot as plt
plt.plot(thresholds, precisions[:-1], label="Precision",marker='x')
plt.plot(thresholds, recalls[:-1], label="Recall",marker='o')
plt.xlabel("Threshold")
plt.ylabel("Score")
plt.legend()
plt.show()

# %%
# confusion matrix - per-class misclassification
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
cm = confusion_matrix(y_test,y_pred)
disp = ConfusionMatrixDisplay(cm,display_labels=np.unique(y_test))
disp.plot(cmap='Blues')
plt.title('Confusion Matrix')
plt.savefig('plots/confusion_matrix.png',bbox_inches='tight',dpi=300)
plt.show()

# %%
from sklearn.metrics import precision_score,recall_score,classification_report

# %%
# precision - of all the positives that were predicted, how many where actual positives?
print(f'Precision Score : {round(precision_score(y_test,y_pred),2) * 100}%')
# Out:
# Precision Score : 92.0%

# %%
# recall - of all the actual positives, how many did we catch?
print(f'Recall Score : {round(recall_score(y_test,y_pred),2)*100}%')
# Out:
# Recall Score : 93.0%

# %%
# classification report - summary report of the model
print('Classification Report\n',classification_report(y_test,y_pred))
# Out:
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98      1405
#            1       0.92      0.93      0.92       284
#
#     accuracy                           0.97      1689
#    macro avg       0.95      0.96      0.95      1689
# weighted avg       0.97      0.97      0.97      1689

# %%
from sklearn.model_selection import learning_curve,LearningCurveDisplay,cross_val_score

# %%
# cross validation scores across five folds - checks for model stability on train set
cv_score = cross_val_score(best_model,x_train,y_train,cv=5,scoring='accuracy')
print('CV Score on Training Set\n')
print('cv_accuracy_score across 5 folds : ',cv_score)
print('mean_cv_score : ',cv_score.mean())
print('std_cv_score : ',cv_score.std())
# Out:
# CV Score on Training Set
#
# cv_accuracy_score across 5 folds :  [0.94930292 0.96192893 0.95431472 0.94035533 0.92766497]
# mean_cv_score :  0.9467133748946491
# std_cv_score :  0.011825952020175404

# %%
# checks for model stability on test set
cv_score = cross_val_score(best_model,x_test,y_pred,cv=5,scoring='accuracy')
print('CV Score on Test Set\n')
print('cv_accuracy_score across 5 folds : ',cv_score)
print('mean_cv_score : ',cv_score.mean())
print('std_cv_score : ',cv_score.std())
# Out:
# CV Score on Test Set
#
# cv_accuracy_score across 5 folds :  [0.91715976 0.9112426  0.92307692 0.93195266 0.94065282]
# mean_cv_score :  0.9248169543307639
# std_cv_score :  0.010465335407261231

# %%
train_sizes, train_scores, test_scores = learning_curve(
    best_model,x_train,y_train,cv = 5, scoring='accuracy',shuffle=True,random_state=42,n_jobs= -1
)
plt.figure(figsize=(10,7))
disp = LearningCurveDisplay(
    train_sizes=train_sizes,
    train_scores=train_scores,
    test_scores=test_scores
)
disp.plot()
plt.title('Learning Curve')
plt.xlabel('Training set sizes')
plt.ylabel('Accuracy')
plt.show()

# %%
from sklearn.metrics import roc_auc_score,roc_curve
# the rate at which model classifiers model well - determines whether model is really learning or just randomly guessing
fpr,tpr,threshold = roc_curve(
    y_test,y_probs
)
auc_score = roc_auc_score(y_test,y_probs)
plt.plot(fpr,tpr,label=f'AUC : {round(auc_score,2)*100}%')
plt.plot([0,1],[0,1],linestyle='--',color='blue')
plt.title('ROC Curve')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.legend()
plt.show()

# %%
# precision recall tradeoff
from sklearn.metrics import precision_recall_curve,average_precision_score
precision,recall,threshold = precision_recall_curve (
    y_test,y_probs
)
pr_auc = average_precision_score(y_test,y_probs)
plt.plot(recall,precision,label=f'PR AUC: {round(pr_auc,2)*100}%',marker='x')
plt.title('Precision Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.legend()
plt.show()

# %%
# compares how well predicted probabilties match real outcomes
from sklearn.calibration import calibration_curve
prob_true, prob_pred = calibration_curve(
    y_test,y_probs, n_bins=10, strategy='uniform'
)
plt.plot(prob_true, prob_pred, marker= 'x')
plt.plot([0,1],[0,1],linestyle='--',color='blue')
plt.title('Calibration Curve')
plt.xlabel("Mean Predicted Probability")
plt.ylabel('Fraction of Positives')
plt.show()

# %%
from sklearn.metrics import brier_score_loss
print('Brier score loss : ',brier_score_loss(y_test,y_pred))
# Out:
# Brier score loss :  0.02545885139135583

# %%
from sklearn.metrics import log_loss
print('Log loss : ',log_loss(y_test,y_pred))
# Out:
# Log loss :  0.9176300152350728

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Probabilities for positive class

plt.figure(figsize=(8,6))
sns.histplot(y_probs[y_test == 1], color="blue", label="Positive class", kde=True, stat="density", bins=20)
sns.histplot(y_probs[y_test == 0], color="red", label="Negative class", kde=True, stat="density", bins=20)

plt.xlabel("Predicted probability for positive class")
plt.ylabel("Density")
plt.title("Probability Distribution of Predictions")
plt.legend()
plt.show()

# %%
from sklearn.metrics import matthews_corrcoef
print('Matthews coefficient : ',matthews_corrcoef(y_test,y_pred))
# Out:
# Matthews coefficient :  0.909393360431276

# %%
from sklearn.metrics import cohen_kappa_score
print('Cohen Kappa Score : ',cohen_kappa_score(y_test,y_pred))
# Out:
# Cohen Kappa Score :  0.9093751832723361

# %%
# error analysis
errors = y_pred != y_test
x_test[errors]

error_analysis = pd.DataFrame(x_test.copy())
error_analysis["y_true"] = y_test
error_analysis["y_pred"] = y_pred
error_analysis['is_error'] = errors.astype(int)

# %%
y_proba = calibrated_model.predict_proba(x_test)
error_analysis['y_probs'] = y_proba.max(axis=1)
# return only rows which were misclassified
error_analysis[error_analysis['is_error'] == 1].sort_values(by='y_probs')
# Out:
#       Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 1660     0.0             Computer         1             32.0
# 815      0.0             Computer         1             32.0
# 531      1.0             Computer         1              9.0
# 746      1.0             Computer         3             15.0
# 1008     1.0             Computer         1             16.0
# 321      1.0           SmartPhone         1              8.0
# 676      1.0           SmartPhone         1              7.0
# 1168     1.0           SmartPhone         1              9.0
# 1372     0.0             Computer         1             22.0
# 474      0.0             Computer         3             14.0
# 253      1.0           SmartPhone         3             14.0
# 239      1.0           SmartPhone         1             30.0
# 414      1.0             Computer         1              9.0
# 317      4.0           SmartPhone         1              8.0
# 489      NaN           SmartPhone         3              8.0
# 901      NaN                Phone         1             20.0
# 139      1.0           SmartPhone         1              9.0
# 1118     1.0           SmartPhone         1              9.0
# 42       9.0             Computer         3             16.0
# 260      0.0                Phone         1              7.0
# 1443    20.0           SmartPhone         1             21.0
# 1654    20.0           SmartPhone         1             13.0
# 591      1.0           SmartPhone         1              9.0
# 1245     1.0           SmartPhone         1             24.0
# 303      1.0             Computer         1             12.0
# 1623     1.0           SmartPhone         1              9.0
# 1222     5.0           SmartPhone         1             19.0
# 813      1.0           SmartPhone         3             30.0
# 885      1.0           SmartPhone         1             24.0
# 98      20.0                Phone         1              NaN
# 1483    20.0                Phone         1              NaN
# 1125     5.0           SmartPhone         1             19.0
# 1085    13.0             Computer         1             35.0
# 1237    16.0           SmartPhone         1              8.0
# 197      0.0                Phone         1             13.0
# 1041     1.0                Phone         3             16.0
# 1        1.0                Phone         3             16.0
# 382     16.0           SmartPhone         1              8.0
# 1271     0.0                Phone         1             13.0
# 1111    16.0           SmartPhone         1             15.0
# 818     16.0           SmartPhone         1             15.0
# 526      3.0           SmartPhone         1             30.0
# 1046     3.0           SmartPhone         1             30.0
#
#      PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 1660                  UPI  Female             NaN                         4
# 815                   UPI  Female             NaN                         4
# 531                   COD  Female             3.0                         4
# 746            Debit Card    Male             3.0                         4
# 1008           Debit Card    Male             3.0                         5
# 321           Credit Card    Male             4.0                         4
# 676           Credit Card    Male             4.0                         4
# 1168          Credit Card    Male             3.0                         4
# 1372                   CC    Male             NaN                         1
# 474            Debit Card    Male             2.0                         3
# 253            Debit Card    Male             3.0                         5
# 239           Credit Card    Male             3.0                         3
# 414                   COD  Female             3.0                         4
# 317           Credit Card  Female             2.0                         5
# 489              E wallet  Female             3.0                         3
# 901            Debit Card    Male             2.0                         3
# 139                   UPI    Male             3.0                         4
# 1118                  UPI    Male             3.0                         4
# 42            Credit Card    Male             2.0                         3
# 260                    CC    Male             NaN                         3
# 1443           Debit Card  Female             4.0                         4
# 1654          Credit Card  Female             2.0                         4
# 591           Credit Card    Male             3.0                         4
# 1245                  COD    Male             3.0                         4
# 303           Credit Card  Female             3.0                         5
# 1623          Credit Card    Male             3.0                         4
# 1222     Cash on Delivery  Female             3.0                         4
# 813              E wallet  Female             3.0                         5
# 885                   COD    Male             3.0                         4
# 98                    COD    Male             2.0                         3
# 1483                  COD    Male             2.0                         3
# 1125     Cash on Delivery  Female             3.0                         4
# 1085           Debit Card    Male             4.0                         5
# 1237     Cash on Delivery  Female             3.0                         4
# 197            Debit Card    Male             3.0                         3
# 1041          Credit Card    Male             3.0                         4
# 1             Credit Card    Male             3.0                         4
# 382      Cash on Delivery  Female             3.0                         4
# 1271           Debit Card    Male             3.0                         3
# 1111          Credit Card    Male             3.0                         5
# 818           Credit Card    Male             3.0                         5
# 526           Credit Card    Male             4.0                         4
# 1046          Credit Card    Male             4.0                         4
#
#         PreferedOrderCat  SatisfactionScore  ... Complain  \
# 1660              Mobile                  3  ...        1
# 815               Mobile                  3  ...        1
# 531           SmartPhone                  1  ...        1
# 746              Fashion                  3  ...        0
# 1008          SmartPhone                  4  ...        0
# 321           SmartPhone                  5  ...        0
# 676           SmartPhone                  5  ...        0
# 1168          SmartPhone                  4  ...        0
# 1372              Mobile                  1  ...        1
# 474              Fashion                  3  ...        0
# 253              Fashion                  2  ...        0
# 239           SmartPhone                  2  ...        1
# 414           SmartPhone                  1  ...        1
# 317           SmartPhone                  1  ...        1
# 489               Mobile                  1  ...        0
# 901               Mobile                  5  ...        1
# 139           SmartPhone                  3  ...        1
# 1118          SmartPhone                  3  ...        1
# 42               Fashion                  2  ...        0
# 260               Mobile                  5  ...        0
# 1443          SmartPhone                  4  ...        1
# 1654             Fashion                  5  ...        1
# 591           SmartPhone                  3  ...        0
# 1245          SmartPhone                  4  ...        1
# 303           SmartPhone                  3  ...        1
# 1623          SmartPhone                  3  ...        0
# 1222              Others                  3  ...        0
# 813   Laptop & Accessory                  1  ...        1
# 885           SmartPhone                  4  ...        1
# 98                Mobile                  3  ...        0
# 1483              Mobile                  3  ...        0
# 1125              Others                  3  ...        0
# 1085  Laptop & Accessory                  5  ...        0
# 1237             Fashion                  1  ...        0
# 197   Laptop & Accessory                  3  ...        0
# 1041          SmartPhone                  1  ...        0
# 1             SmartPhone                  1  ...        0
# 382              Fashion                  1  ...        0
# 1271  Laptop & Accessory                  3  ...        0
# 1111  Laptop & Accessory                  4  ...        0
# 818   Laptop & Accessory                  4  ...        0
# 526           SmartPhone                  5  ...        0
# 1046          SmartPhone                  5  ...        0
#
#       OrderAmountHikeFromlastYear  CouponUsed  OrderCount  DaySinceLastOrder  \
# 1660                         14.0         1.0         1.0                3.0
# 815                          14.0         0.0         1.0                3.0
# 531                          14.0         2.0         2.0                4.0
# 746                          16.0         2.0         2.0                NaN
# 1008                         12.0         2.0         2.0                1.0
# 321                          14.0         8.0         8.0                7.0
# 676                          14.0         4.0         8.0                7.0
# 1168                         13.0         2.0         3.0                3.0
# 1372                         13.0         0.0         1.0                0.0
# 474                          15.0         1.0         1.0                7.0
# 253                          22.0         2.0         NaN                2.0
# 239                          12.0         1.0         2.0                5.0
# 414                          14.0         1.0         2.0                4.0
# 317                          11.0         0.0         1.0                0.0
# 489                          13.0         2.0         2.0                2.0
# 901                          14.0         5.0         6.0                8.0
# 139                          20.0         1.0         2.0                3.0
# 1118                         20.0         1.0         2.0                3.0
# 42                           14.0         1.0         9.0                7.0
# 260                          13.0         7.0         7.0                6.0
# 1443                         19.0         4.0         5.0                4.0
# 1654                         14.0         1.0         5.0                9.0
# 591                          18.0         3.0         3.0                2.0
# 1245                         17.0         1.0         2.0                2.0
# 303                          15.0         1.0         2.0                8.0
# 1623                         18.0         1.0         3.0                2.0
# 1222                          NaN        10.0        16.0                9.0
# 813                          20.0         1.0         2.0                1.0
# 885                          17.0         2.0         2.0                2.0
# 98                           24.0         1.0         1.0                0.0
# 1483                         24.0         0.0         1.0                0.0
# 1125                          NaN         2.0        16.0                9.0
# 1085                         21.0         1.0         2.0                4.0
# 1237                         16.0         1.0         1.0                9.0
# 197                          18.0         1.0         1.0                1.0
# 1041                         14.0         1.0         2.0                1.0
# 1                            14.0         1.0         2.0                1.0
# 382                          16.0         0.0         1.0                9.0
# 1271                         18.0         0.0         1.0                1.0
# 1111                         16.0         8.0         8.0                8.0
# 818                          16.0         8.0         8.0                8.0
# 526                          14.0         1.0         2.0                4.0
# 1046                         14.0         1.0         2.0                4.0
#
#       CashbackAmount  y_true  y_pred  is_error   y_probs
# 1660             128       0       1         1  0.530467
# 815              128       0       1         1  0.546663
# 531              163       0       1         1  0.547750
# 746              212       0       1         1  0.548593
# 1008             152       0       1         1  0.604311
# 321              154       0       1         1  0.629890
# 676              154       0       1         1  0.629947
# 1168             160       0       1         1  0.632319
# 1372             129       0       1         1  0.645701
# 474              187       0       1         1  0.712679
# 253              241       0       1         1  0.713727
# 239              152       0       1         1  0.721868
# 414              163       0       1         1  0.724888
# 317              111       0       1         1  0.751860
# 489              120       0       1         1  0.766394
# 901              122       0       1         1  0.771810
# 139              165       0       1         1  0.772544
# 1118             165       0       1         1  0.772544
# 42               200       0       1         1  0.777587
# 260              129       0       1         1  0.799844
# 1443             175       1       0         1  0.821651
# 1654             200       1       0         1  0.896879
# 591              169       1       0         1  0.906676
# 1245             156       0       1         1  0.918329
# 303              149       1       0         1  0.937539
# 1623             169       1       0         1  0.940452
# 1222             320       1       0         1  0.944760
# 813              167       0       1         1  0.945270
# 885              156       0       1         1  0.955356
# 98               125       1       0         1  0.961203
# 1483             125       1       0         1  0.963628
# 1125             320       1       0         1  0.963896
# 1085             168       1       0         1  0.964464
# 1237             202       1       0         1  0.966940
# 197              149       1       0         1  0.967194
# 1041             136       1       0         1  0.967359
# 1                136       1       0         1  0.967359
# 382              202       1       0         1  0.967393
# 1271             149       1       0         1  0.967672
# 1111             174       1       0         1  0.967810
# 818              174       1       0         1  0.968199
# 526              164       1       0         1  0.968743
# 1046             164       1       0         1  0.968743
#
# [43 rows x 22 columns]

# %%
high_conf_err = error_analysis[(error_analysis['is_error'] == 1) & (error_analysis['y_probs'] >= 0.9)]
low_conf_err = error_analysis[(error_analysis['is_error'] == 1) & (error_analysis['y_probs'] < 0.6)]

# %%
high_conf_err.sort_values(by='y_probs',ascending=False)
# Out:
#       Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 526      3.0           SmartPhone         1             30.0
# 1046     3.0           SmartPhone         1             30.0
# 818     16.0           SmartPhone         1             15.0
# 1111    16.0           SmartPhone         1             15.0
# 1271     0.0                Phone         1             13.0
# 382     16.0           SmartPhone         1              8.0
# 1041     1.0                Phone         3             16.0
# 1        1.0                Phone         3             16.0
# 197      0.0                Phone         1             13.0
# 1237    16.0           SmartPhone         1              8.0
# 1085    13.0             Computer         1             35.0
# 1125     5.0           SmartPhone         1             19.0
# 1483    20.0                Phone         1              NaN
# 98      20.0                Phone         1              NaN
# 885      1.0           SmartPhone         1             24.0
# 813      1.0           SmartPhone         3             30.0
# 1222     5.0           SmartPhone         1             19.0
# 1623     1.0           SmartPhone         1              9.0
# 303      1.0             Computer         1             12.0
# 1245     1.0           SmartPhone         1             24.0
# 591      1.0           SmartPhone         1              9.0
#
#      PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 526           Credit Card    Male             4.0                         4
# 1046          Credit Card    Male             4.0                         4
# 818           Credit Card    Male             3.0                         5
# 1111          Credit Card    Male             3.0                         5
# 1271           Debit Card    Male             3.0                         3
# 382      Cash on Delivery  Female             3.0                         4
# 1041          Credit Card    Male             3.0                         4
# 1             Credit Card    Male             3.0                         4
# 197            Debit Card    Male             3.0                         3
# 1237     Cash on Delivery  Female             3.0                         4
# 1085           Debit Card    Male             4.0                         5
# 1125     Cash on Delivery  Female             3.0                         4
# 1483                  COD    Male             2.0                         3
# 98                    COD    Male             2.0                         3
# 885                   COD    Male             3.0                         4
# 813              E wallet  Female             3.0                         5
# 1222     Cash on Delivery  Female             3.0                         4
# 1623          Credit Card    Male             3.0                         4
# 303           Credit Card  Female             3.0                         5
# 1245                  COD    Male             3.0                         4
# 591           Credit Card    Male             3.0                         4
#
#         PreferedOrderCat  SatisfactionScore  ... Complain  \
# 526           SmartPhone                  5  ...        0
# 1046          SmartPhone                  5  ...        0
# 818   Laptop & Accessory                  4  ...        0
# 1111  Laptop & Accessory                  4  ...        0
# 1271  Laptop & Accessory                  3  ...        0
# 382              Fashion                  1  ...        0
# 1041          SmartPhone                  1  ...        0
# 1             SmartPhone                  1  ...        0
# 197   Laptop & Accessory                  3  ...        0
# 1237             Fashion                  1  ...        0
# 1085  Laptop & Accessory                  5  ...        0
# 1125              Others                  3  ...        0
# 1483              Mobile                  3  ...        0
# 98                Mobile                  3  ...        0
# 885           SmartPhone                  4  ...        1
# 813   Laptop & Accessory                  1  ...        1
# 1222              Others                  3  ...        0
# 1623          SmartPhone                  3  ...        0
# 303           SmartPhone                  3  ...        1
# 1245          SmartPhone                  4  ...        1
# 591           SmartPhone                  3  ...        0
#
#       OrderAmountHikeFromlastYear  CouponUsed  OrderCount  DaySinceLastOrder  \
# 526                          14.0         1.0         2.0                4.0
# 1046                         14.0         1.0         2.0                4.0
# 818                          16.0         8.0         8.0                8.0
# 1111                         16.0         8.0         8.0                8.0
# 1271                         18.0         0.0         1.0                1.0
# 382                          16.0         0.0         1.0                9.0
# 1041                         14.0         1.0         2.0                1.0
# 1                            14.0         1.0         2.0                1.0
# 197                          18.0         1.0         1.0                1.0
# 1237                         16.0         1.0         1.0                9.0
# 1085                         21.0         1.0         2.0                4.0
# 1125                          NaN         2.0        16.0                9.0
# 1483                         24.0         0.0         1.0                0.0
# 98                           24.0         1.0         1.0                0.0
# 885                          17.0         2.0         2.0                2.0
# 813                          20.0         1.0         2.0                1.0
# 1222                          NaN        10.0        16.0                9.0
# 1623                         18.0         1.0         3.0                2.0
# 303                          15.0         1.0         2.0                8.0
# 1245                         17.0         1.0         2.0                2.0
# 591                          18.0         3.0         3.0                2.0
#
#       CashbackAmount  y_true  y_pred  is_error   y_probs
# 526              164       1       0         1  0.968743
# 1046             164       1       0         1  0.968743
# 818              174       1       0         1  0.968199
# 1111             174       1       0         1  0.967810
# 1271             149       1       0         1  0.967672
# 382              202       1       0         1  0.967393
# 1041             136       1       0         1  0.967359
# 1                136       1       0         1  0.967359
# 197              149       1       0         1  0.967194
# 1237             202       1       0         1  0.966940
# 1085             168       1       0         1  0.964464
# 1125             320       1       0         1  0.963896
# 1483             125       1       0         1  0.963628
# 98               125       1       0         1  0.961203
# 885              156       0       1         1  0.955356
# 813              167       0       1         1  0.945270
# 1222             320       1       0         1  0.944760
# 1623             169       1       0         1  0.940452
# 303              149       1       0         1  0.937539
# 1245             156       0       1         1  0.918329
# 591              169       1       0         1  0.906676
#
# [21 rows x 22 columns]

# %%
low_conf_err.sort_values(by='y_probs',ascending=False)
# Out:
#       Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 746      1.0             Computer         3             15.0
# 531      1.0             Computer         1              9.0
# 815      0.0             Computer         1             32.0
# 1660     0.0             Computer         1             32.0
#
#      PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 746            Debit Card    Male             3.0                         4
# 531                   COD  Female             3.0                         4
# 815                   UPI  Female             NaN                         4
# 1660                  UPI  Female             NaN                         4
#
#      PreferedOrderCat  SatisfactionScore  ... Complain  \
# 746           Fashion                  3  ...        0
# 531        SmartPhone                  1  ...        1
# 815            Mobile                  3  ...        1
# 1660           Mobile                  3  ...        1
#
#       OrderAmountHikeFromlastYear  CouponUsed  OrderCount  DaySinceLastOrder  \
# 746                          16.0         2.0         2.0                NaN
# 531                          14.0         2.0         2.0                4.0
# 815                          14.0         0.0         1.0                3.0
# 1660                         14.0         1.0         1.0                3.0
#
#       CashbackAmount  y_true  y_pred  is_error   y_probs
# 746              212       0       1         1  0.548593
# 531              163       0       1         1  0.547750
# 815              128       0       1         1  0.546663
# 1660             128       0       1         1  0.530467
#
# [4 rows x 22 columns]

# %%
pd.crosstab(error_analysis['MaritalStatus'],error_analysis['is_error'],normalize=True)*100
# Out:
# is_error               0         1
# MaritalStatus
# Divorced       15.216104  0.296033
# Married        49.970397  1.243339
# Single         32.267614  1.006513

# %%
pd.crosstab(error_analysis['PreferedOrderCat'],error_analysis['is_error'],normalize=True) *100
# Out:
# is_error                    0         1
# PreferedOrderCat
# Fashion             13.143872  0.414446
# Grocery              7.045589  0.000000
# Laptop & Accessory  36.944938  0.355240
# Mobile              13.795145  0.473653
# Others               5.210184  0.118413
# SmartPhone          21.314387  1.184133

# %%
# feature error analysis for preferedordercat - shows counts, number of errros and error rates
error_rate = error_analysis.groupby('PreferedOrderCat')['is_error'].mean()
counts = error_analysis.groupby('PreferedOrderCat')['is_error'].count()
errors = error_analysis.groupby('PreferedOrderCat')['is_error'].sum()
summary = pd.DataFrame({
    'error_rate' : error_rate,
    'counts' : counts,
    'errors' : errors
})
summary
# Out:
#                     error_rate  counts  errors
# PreferedOrderCat
# Fashion               0.030568     229       7
# Grocery               0.000000     119       0
# Laptop & Accessory    0.009524     630       6
# Mobile                0.033195     241       8
# Others                0.022222      90       2
# SmartPhone            0.052632     380      20

# %%
num_features = error_analysis.select_dtypes(include='number').columns.drop('is_error')
# mean/median difference
mean_diff = error_analysis.groupby('is_error')[num_features].mean().T
median_diff = error_analysis.groupby('is_error')[num_features].median().T

# correlation with error
correlations = error_analysis[num_features].corrwith(error_analysis['is_error']).sort_values(ascending=False)

print('Mean Difference : \n',mean_diff)
print('\nMedian Diff : \n',median_diff)
print('\nCorrelation with error : \n',correlations)
# Out:
# Mean Difference :
#  is_error                              0           1
# Tenure                        10.394636    5.000000
# CityTier                       1.640340    1.372093
# WarehouseToHome               15.560328   16.414634
# HourSpendOnApp                 2.935587    2.974359
# NumberOfDeviceRegistered       3.677400    3.883721
# SatisfactionScore              3.078372    3.000000
# NumberOfAddress                4.239976    3.953488
# Complain                       0.291009    0.372093
# OrderAmountHikeFromlastYear   15.798206   15.975610
# CouponUsed                     1.719008    2.162791
# OrderCount                     3.008254    3.571429
# DaySinceLastOrder              4.543115    4.119048
# CashbackAmount               177.938639  167.069767
# y_true                         0.160389    0.465116
# y_pred                         0.160389    0.534884
# y_probs                        0.949115    0.823230
#
# Median Diff :
#  is_error                             0           1
# Tenure                         9.00000    1.000000
# CityTier                       1.00000    1.000000
# WarehouseToHome               13.00000   15.000000
# HourSpendOnApp                 3.00000    3.000000
# NumberOfDeviceRegistered       4.00000    4.000000
# SatisfactionScore              3.00000    3.000000
# NumberOfAddress                3.00000    3.000000
# Complain                       0.00000    0.000000
# OrderAmountHikeFromlastYear   15.00000   15.000000
# CouponUsed                     1.00000    1.000000
# OrderCount                     2.00000    2.000000
# DaySinceLastOrder              3.00000    3.500000
# CashbackAmount               164.00000  163.000000
# y_true                         0.00000    0.000000
# y_pred                         0.00000    1.000000
# y_probs                        0.96881    0.896879
#
# Correlation with error :
#  y_pred                         0.157065
# y_true                         0.128340
# CouponUsed                     0.038129
# NumberOfDeviceRegistered       0.032020
# OrderCount                     0.029947
# Complain                       0.028060
# WarehouseToHome                0.015491
# HourSpendOnApp                 0.008255
# OrderAmountHikeFromlastYear    0.007531
# SatisfactionScore             -0.009058
# NumberOfAddress               -0.017174
# DaySinceLastOrder             -0.018438
# CashbackAmount                -0.034185
# CityTier                      -0.046407
# Tenure                        -0.099314
# y_probs                       -0.282550
# dtype: float64

# %%
feature_names = best_model.named_steps.get('preprocessor',None).get_feature_names_out() # get feature names
importance = best_model.named_steps.get('classifier',None).feature_importances_ # get feature importance

feature_imp = pd.DataFrame({
    'features' : feature_names,
    'importance' : importance
}).sort_values(by='importance',ascending=False).head(10).plot.bar(x='features',y='importance',figsize=(16,8),color='indigo')
plt.title('Feature Importance')
plt.savefig('plots/feature_importance.png',bbox_inches='tight',dpi=300)
plt.show()

# %%
import shap
x_test_transformed = best_model.named_steps.get('preprocessor',None).transform(x_test)
explainer = shap.TreeExplainer(best_model.named_steps['classifier'])
shap_values = explainer(x_test_transformed)

plt.figure(figsize=(20,7))
shap.summary_plot(shap_values,x_test_transformed,feature_names=feature_names,show=False)
plt.savefig('plots/shap_summary.png',bbox_inches='tight',dpi=300)
plt.show()
