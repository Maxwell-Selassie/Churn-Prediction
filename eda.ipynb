# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/E-commerce.csv') # load csv into the env as a pandas dataFrame

# %%
df.head() # prints out the first 5 rows of the dataset
# Out:
#    CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0       50001      1     4.0         Mobile Phone         3              6.0
# 1       50002      1     NaN                Phone         1              8.0
# 2       50003      1     NaN                Phone         1             30.0
# 3       50004      1     0.0                Phone         3             15.0
# 4       50005      1     0.0                Phone         1             12.0
#
#   PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0           Debit Card  Female             3.0                         3
# 1                  UPI    Male             3.0                         4
# 2           Debit Card    Male             2.0                         4
# 3           Debit Card    Male             2.0                         4
# 4                   CC    Male             NaN                         3
#
# ...

# %%
df.tail() # prints out the last 5 rows of the dataset
# Out:
#       CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  \
# 5625       55626      0    10.0             Computer         1
# 5626       55627      0    13.0         Mobile Phone         1
# 5627       55628      0     1.0         Mobile Phone         1
# 5628       55629      0    23.0             Computer         3
# 5629       55630      0     8.0         Mobile Phone         1
#
#       WarehouseToHome PreferredPaymentMode Gender  HourSpendOnApp  \
# 5625             30.0          Credit Card   Male             3.0
# 5626             13.0          Credit Card   Male             3.0
# 5627             11.0           Debit Card   Male             3.0
# 5628              9.0          Credit Card   Male             4.0
# 5629             15.0          Credit Card   Male             3.0
#
#       NumberOfDeviceRegistered    PreferedOrderCat  SatisfactionScore  \
# 5625                         2  Laptop & Accessory                  1
# ...

# %%
df.info() # prints out column names, non-null counts and respective data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5630 entries, 0 to 5629
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CustomerID                   5630 non-null   int64
#  1   Churn                        5630 non-null   int64
#  2   Tenure                       5366 non-null   float64
#  3   PreferredLoginDevice         5630 non-null   object
#  4   CityTier                     5630 non-null   int64
#  5   WarehouseToHome              5379 non-null   float64
#  6   PreferredPaymentMode         5630 non-null   object
#  7   Gender                       5630 non-null   object
#  8   HourSpendOnApp               5375 non-null   float64
#  9   NumberOfDeviceRegistered     5630 non-null   int64
#  10  PreferedOrderCat             5630 non-null   object
#  11  SatisfactionScore            5630 non-null   int64
#  12  MaritalStatus                5630 non-null   object
# ...

# %%
df.shape #prints out the number of rows and columns (5630 rows, 20 columns)
# Out:
# (5630, 20)

# %%
df.describe(include='all').T # a statistical summary of the dataset
# Out:
#                               count unique                 top  freq  \
# CustomerID                   5630.0    NaN                 NaN   NaN
# Churn                        5630.0    NaN                 NaN   NaN
# Tenure                       5366.0    NaN                 NaN   NaN
# PreferredLoginDevice           5630      3        Mobile Phone  2765
# CityTier                     5630.0    NaN                 NaN   NaN
# WarehouseToHome              5379.0    NaN                 NaN   NaN
# PreferredPaymentMode           5630      7          Debit Card  2314
# Gender                         5630      2                Male  3384
# HourSpendOnApp               5375.0    NaN                 NaN   NaN
# NumberOfDeviceRegistered     5630.0    NaN                 NaN   NaN
# PreferedOrderCat               5630      6  Laptop & Accessory  2050
# SatisfactionScore            5630.0    NaN                 NaN   NaN
# MaritalStatus                  5630      3             Married  2986
# ...

# %%
# divide columns into numeric and categorical columns
numeric_cols = df.select_dtypes(include=[np.number]).columns
categorical_cols = df.select_dtypes(include='object').columns

# %%
#numerical columns
cols = [col for col in numeric_cols[1:]] # ignore customerID column
print(f'Numerical columns: {cols} - {len(cols)}')
# Out:
# Numerical columns: ['Churn', 'Tenure', 'CityTier', 'WarehouseToHome', 'HourSpendOnApp', 'NumberOfDeviceRegistered', 'SatisfactionScore', 'NumberOfAddress', 'Complain', 'OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount', 'DaySinceLastOrder', 'CashbackAmount'] - 14

# %%
for cols in numeric_cols[1:]:
    print(f'{cols:<27} - Min: {df[cols].min():<12} - Max: {df[cols].max()}')
# Out:
# Churn                       - Min: 0            - Max: 1
# Tenure                      - Min: 0.0          - Max: 61.0
# CityTier                    - Min: 1            - Max: 3
# WarehouseToHome             - Min: 5.0          - Max: 127.0
# HourSpendOnApp              - Min: 0.0          - Max: 5.0
# NumberOfDeviceRegistered    - Min: 1            - Max: 6
# SatisfactionScore           - Min: 1            - Max: 5
# NumberOfAddress             - Min: 1            - Max: 22
# Complain                    - Min: 0            - Max: 1
# OrderAmountHikeFromlastYear - Min: 11.0         - Max: 26.0
# CouponUsed                  - Min: 0.0          - Max: 16.0
# OrderCount                  - Min: 1.0          - Max: 16.0
# DaySinceLastOrder           - Min: 0.0          - Max: 46.0
# CashbackAmount              - Min: 0            - Max: 325

# %% [markdown]
# **Numerical Columns Description**
# Churn : Target variable (0 = customer stayed, 1 = customer churned/left)
# Tenure : How long the customer has stayed with the company
# CityTier : Classification of the city where the customer lives
# WarehouseToHome : Distance between the warehouse and the customer's home
# HoursSpendOnApp : Average hours the customer spends on the app per day/week
# NumberOfDeviceRegistered : Number of devices registered to a cutomer's account
# SatisfactionScore: A customer's satisfaction rating
# NumberOfAddress : How many addresses the customer has saved
# Complain : Whether the customer has filed a complaint or not
# OrderAmountHikeFromlastYear : Percentage increase in order compared to last year
# CouponUsed : Number of coupons used by the customer
# OrderCount : Number of orders placed by the customer
# DaysSinceLastOrder : Number of days since the customer's last order
# CashbackAmount : Total cashback the customer has received

# %%
df.drop(columns=['CustomerID'],inplace=True)

# %%
#categorical columns
cols = [col for col in categorical_cols]
print(f'Categorical columns : {cols} - {len(cols)}')
# Out:
# Categorical columns : ['PreferredLoginDevice', 'PreferredPaymentMode', 'Gender', 'PreferedOrderCat', 'MaritalStatus'] - 5

# %%
for cols in categorical_cols:
    print(f'-{cols:<20} - {df[cols].unique()} - {len(df[cols].unique())}\n')
# Out:
# -PreferredLoginDevice - ['Mobile Phone' 'Phone' 'Computer'] - 3
#
# -PreferredPaymentMode - ['Debit Card' 'UPI' 'CC' 'Cash on Delivery' 'E wallet' 'COD' 'Credit Card'] - 7
#
# -Gender               - ['Female' 'Male'] - 2
#
# -PreferedOrderCat     - ['Laptop & Accessory' 'Mobile' 'Mobile Phone' 'Others' 'Fashion' 'Grocery'] - 6
#
# -MaritalStatus        - ['Single' 'Divorced' 'Married'] - 3

# %% [markdown]
# **Categorical columns description**
# PreferredLoginDevice - The device most often used to log into the app/site
# PreferredPaymentMode - Payment method most often used
# Gender - Sex of the customer (male/female)
# PreferredOrderCat - Most frequent product category ordered
# MaritalStatus - Marital status of the customer

# %%
#missing data
missing = df.isnull().sum()
missing = missing[missing>0].sort_values(ascending=False)
missing_pct = missing / len(df)

missing_df = pd.DataFrame({
    'missing value' : missing,
    'missing pct' : missing_pct
})
print(missing_df)
# Out:
#                              missing value  missing pct
# DaySinceLastOrder                      307     0.054529
# OrderAmountHikeFromlastYear            265     0.047069
# Tenure                                 264     0.046892
# OrderCount                             258     0.045826
# CouponUsed                             256     0.045471
# HourSpendOnApp                         255     0.045293
# WarehouseToHome                        251     0.044583

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
missing.plot(kind='bar',width=0.5,color='indigo')
plt.title('Missing Data')

plt.subplot(1,2,2)
missing.plot.pie(autopct='%1.1f%%')
plt.show()

# %%
#duplicated rows
df[df.duplicated(keep='first')]
# Out:
#       Churn  Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 1347      1     NaN                Phone         1              8.0
# 1359      1     NaN                Phone         1             30.0
# 1395      1    11.0         Mobile Phone         1              6.0
# 1456      1     0.0             Computer         1             13.0
# 1485      1     0.0                Phone         1             15.0
# ...     ...     ...                  ...       ...              ...
# 5611      0    12.0         Mobile Phone         3             17.0
# 5613      0    10.0         Mobile Phone         3             18.0
# 5620      0     3.0         Mobile Phone         1             35.0
# 5625      0    10.0             Computer         1             30.0
# 5628      0    23.0             Computer         3              9.0
#
#      PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# ...

# %%
#correlation between numeric data using the spearman method
corr = df.corr(method='spearman',numeric_only=True)
plt.figure(figsize=(10,5))
sns.heatmap(data=corr,annot=True,fmt='.2f',cmap='magma')
plt.title('Correlation between numeric columns')
plt.show()

# %%
#gender and churn relationship
plt.figure(figsize=(18,6))
plt.subplot(1,2,1)
ax = sns.countplot(data=df,x='Gender',gap=0.2,width=0.5,saturation=0.75,hue='Churn',palette='seismic')
plt.ylabel('Frequency')
for container in ax.containers:
    ax.bar_label(container,label_type='edge',fontsize=10)
plt.title('Relationship between Gender and Churn',fontsize=13,fontweight=10)

plt.subplot(1,2,2)
plt.pie(data=df,x=df['Gender'].value_counts(),labels=df['Gender'].unique(),
        explode=[0.03,0.03],
        autopct='%1.1f%%',
        shadow=True,
        colors=['indigo','orange'])
plt.title('Gender',fontsize=13,fontweight=10)
plt.show()

# %%
#PreferredLoginDevice and Churn Relationship
plt.figure(figsize=(18,6))
plt.subplot(1,2,1)
ax = sns.countplot(data=df,x='PreferredLoginDevice',gap=0.2,width=0.5,saturation=0.75,hue='Churn',palette='magma')
plt.ylabel('Frequency')
for container in ax.containers:
    ax.bar_label(container,label_type='edge',fontsize=10)
plt.title('Relationship between PreferredLoginDevice Status and Churn',fontsize=13,fontweight=10)

plt.subplot(1,2,2)
plt.pie(data=df,x=df['PreferredLoginDevice'].value_counts(),labels=df['PreferredLoginDevice'].unique(),
        explode=[0.03,0.03,0.03],
        autopct='%1.1f%%',
        shadow=True,
        colors=['indigo','orange','green'])
plt.title('Preferred Login Device',fontsize=13,fontweight=10)
plt.show()

# %%
#Marital Status and Churn relationship
plt.figure(figsize=(18,6))
plt.subplot(1,2,1)
ax = sns.countplot(data=df,x='MaritalStatus',gap=0.2,width=0.5,saturation=0.75,hue='Churn',palette='inferno')
plt.ylabel('Frequency')
for container in ax.containers:
    ax.bar_label(container,label_type='edge',fontsize=10)
plt.title('Relationship between Marital Status and Churn',fontsize=13,fontweight=10)

plt.subplot(1,2,2)
plt.pie(data=df,x=df['MaritalStatus'].value_counts(),labels=df['MaritalStatus'].unique(),
        explode=[0.03,0.03,0.03],
        autopct='%1.1f%%',
        shadow=True,
        colors=['indigo','orange','green'])
plt.title('Marital Status',fontsize=13,fontweight=10)
plt.show()

# %%
# PreferredOrderCat and Churn relationship
plt.figure(figsize=(18,6))
plt.subplot(1,2,1)
ax = sns.countplot(data=df,x='PreferedOrderCat',gap=0.2,width=0.5,saturation=0.75,hue='Churn',palette='seismic')
plt.ylabel('Frequency')
for container in ax.containers:
    ax.bar_label(container,label_type='edge',fontsize=10)
plt.title('Relationship between PreferedOrderCat and Churn',fontsize=13,fontweight=10)

plt.subplot(1,2,2)
plt.pie(data=df,x=df['PreferedOrderCat'].value_counts(),labels=df['PreferedOrderCat'].unique(),
        autopct='%1.1f%%',
        shadow=True)
plt.title('Preferred Order Category',fontsize=13,fontweight=10)
plt.show()

# %%
#relationship between PreferredPaymentMode and Churn
plt.figure(figsize=(18,6))
plt.subplot(1,2,1)
ax = sns.countplot(data=df,x='PreferredPaymentMode',gap=0.2,width=0.5,saturation=0.75,hue='Churn',palette='seismic')
plt.ylabel('Frequency')
for container in ax.containers:
    ax.bar_label(container,label_type='edge',fontsize=10)
plt.title('Relationship between PreferredPaymentMode and Churn',fontsize=13,fontweight=10)

plt.subplot(1,2,2)
plt.pie(data=df,x=df['PreferredPaymentMode'].value_counts(),labels=df['PreferredPaymentMode'].unique(),
        autopct='%1.1f%%',
        shadow=True)
plt.title('Preferred Payment Mode',fontsize=13,fontweight=10)
plt.show()

# %%
sns.pairplot(data=df)
plt.show()

# %%
df.to_csv('data/preprocessed_df.csv',index=False)
print('Preprocessed data successfully saved!')
# Out:
# Preprocessed data successfully saved!
